# %%
import mlflow
import mlflow.sklearn

# %%
from sklearn.datasets import load_boston

# %%
X,y = load_boston(return_X_y=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import median_absolute_error

# %%
mlflow.set_experiment('1')
# Out:
# INFO: '1' does not exist. Creating a new experiment

# %%
with mlflow.start_run():
    lr = LinearRegression()
    lr.fit(X_train,y_train)
    score = lr.score(X_test,y_test)
    mlflow.log_metric('r2',score)
    mlflow.sklearn.log_model(lr,'model')
    mlflow.log_metric('mae',median_absolute_error(y_test,lr.predict(X_test)))

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
for k in range(1,11):
    with mlflow.start_run():
        knn = KNeighborsRegressor(n_neighbors=k)
        knn.fit(X_train,y_train)
        score = knn.score(X_test,y_test)
        mlflow.log_param('k',k)
        mlflow.log_param('modelo','knn')
        mlflow.log_metric('r2',score)
        mlflow.sklearn.log_model(knn,'model')
        mlflow.log_metric('mae',median_absolute_error(y_test,knn.predict(X_test)))
        mlflow.log_metric('r2_treino',knn.score(X_train,y_train))
        mlflow.log_metric('mae_treino',median_absolute_error(y_train,knn.predict(X_train)))

# %%
mlflow.set_experiment('autoflow2')
# Out:
# INFO: 'autoflow2' does not exist. Creating a new experiment

# %%
mlflow.sklearn.autolog()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
X,y=load_breast_cancer(return_X_y=True)
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
for est in [50,100,200]:
    for max_depth in list(range(1,11))+[None]:
        with mlflow.start_run():
            rf = RandomForestClassifier(n_estimators=est, max_depth=max_depth)
            rf.fit(X_train,y_train)
            preds = rf.predict(X_test)
            mlflow.log_metric('accuracy',accuracy_score(y_test,preds))
            mlflow.log_metric('precision',precision_score(y_test,preds))
            mlflow.log_metric('recall',recall_score(y_test,preds))
            mlflow.log_metric('f1',f1_score(y_test,preds))
            print('\n')
# Out:
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:15 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '23266da9bab840a88ff965b057678a73'
# 2021/02/06 08:59:16 WARNING mlflow.utils.autologging_utils: MLflow issued a warning during sklearn autologging: "C:\Users\Lucas\anaconda3\lib\site-packages\mlflow\models\signature.py:124: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:16 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '4c81f20a06784ccb9848baccb6a59885'
# 2021/02/06 08:59:17 WARNING mlflow.utils.autologging_utils: MLflow issued a warning during sklearn autologging: "C:\Users\Lucas\anaconda3\lib\site-packages\mlflow\models\signature.py:124: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:17 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID 'c12dd67b153f4d1382eddcdc4435b35e'
# 2021/02/06 08:59:18 WARNING mlflow.utils.autologging_utils: MLflow issued a warning during sklearn autologging: "C:\Users\Lucas\anaconda3\lib\site-packages\mlflow\models\signature.py:124: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# 2021/02/06 08:59:18 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '8f1cedb6317444a6814e5d569a6c1234'
# ...
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:52 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:53 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:53 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:53 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:53 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:53 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '851c7071cf1341ab985f292f0dda66b2'
# 2021/02/06 08:59:53 WARNING mlflow.utils.autologging_utils: MLflow issued a warning during sklearn autologging: "C:\Users\Lucas\anaconda3\lib\site-packages\mlflow\models\signature.py:124: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."

# %%
rf = mlflow.sklearn.load_model('model/')

# %%
rf.score(X_test,y_test)
# Out:
# 0.9370629370629371

# %%
mlflow.sklearn.save_model(rf,'rf_model/')

# %%
from sklearn.datasets import load_iris

# %%
X,y = load_iris(return_X_y=True)
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
rf.score(X_test,y_test)
# Out:
# 2021/02/06 09:27:02 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3fff41d21cf94a9083145b05ee1c989f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 INFO mlflow.utils.autologging_utils: sklearn autologging will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow to the MLflow run with ID '3fff41d21cf94a9083145b05ee1c989f'
# 2021/02/06 09:27:03 WARNING mlflow.utils.autologging_utils: MLflow issued a warning during sklearn autologging: "C:\Users\Lucas\anaconda3\lib\site-packages\mlflow\models\signature.py:124: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 0.9473684210526315

# %%
mlflow.sklearn.save_model(rf,'served_model/')

# %%
X_test[0:2]
# Out:
# array([[5.5, 2.4, 3.8, 1.1],
#        [6. , 3. , 4.8, 1.8]])

# %%
rf.predict(X_test[0:2])
# Out:
# array([1, 2])

# %% [markdown]
# Precisa estar no ambiente do anaconda (conda) <br>
# anaconda3/Scripts/activate
#
# Servindo o modelo <br>
# mlflow models serve -m lr_model/ -h 0.0.0.0 -p 8001
#
# Executando requisições <br>
# curl -X POST -H "Content-Type:application/json; format=pandas-split" --data "{\"columns\":[\"a\", \"b\", \"c\", \"d\"],\"data\":[[]]}" http://127.0.0.1:8001/invocations

# %%
import requests
import pandas as pd

host = '127.0.0.1'
port = '8001'

url = f'http://{host}:{port}/invocations'

headers = {'Content-Type':'application/json'}

http_data = pd.DataFrame([X_test[0]],columns=['a','b','c','d']).to_json(orient='split')

r = requests.post(url=url, headers=headers, data=http_data)

print(f'Predictions: {r.text}')
# Out:
# Predictions: [1]
